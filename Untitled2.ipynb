# %%
import numpy as np
import pandas as pd 
from functools import reduce
from operator import itemgetter
from userCF import UserCF
import time
#numpy.random.choice 很有用
class LFM(UserCF):
	"""docstring for LFM"""
	def __init__(self, filePath,iter_num,hid_cla,learning_rate,lambdas,commend_num=10):
		super().__init__(filePath=filePath,commend_num=commend_num,k=0)
		self.iter_num=iter_num
		self.hid_cla=hid_cla
		self.learning_rate=learning_rate
		self.lambdas=lambdas
	
	def __RandomSelectNegativeSample(self):
		#计算正样本
		self.train_data  = {}
		for user,items in self.train.items():
			user_data = {}
			for item in items:
				user_data[item] = 1
			self.train_data[user] = user_data
		#计算流行度
		self.__itemPopularity()
		sums = sum(self.item_popularity.values())
		posibility = np.array(list(self.item_popularity.values()))/sums

		#采样负样本
		step=0
		max_len = len(posibility)
		lens = len(self.train.keys())
		for user,item in self.train.items():
			num = len(item)
			neg_num = min(max_len,3*num)
			sample = set(np.random.choice(list(self.item_popularity.keys()),neg_num,False,posibility))
			original = set(self.train_data[user].keys())
			new = sample - original
			if num-len(new)>=0:
				for item in new:
					self.train_data[user][item] = 0
				lenss = len(new)
			else:
				for i in range(num):
					self.train_data[user][new.pop()] = 0
				lenss = num

			print("step=%d,bili = %f, ratio=%d"%(step,step/lens,lenss/num))
			step+=1


	def __trainLFM(self):
		st = time.time()
		for step in range(self.iter_num):
			print("step = %d"%step)
			print(time.time()-st)
			for user,items in self.train_data.items():
				sigma = []
				lengths = len(items)
				for item , rui in items.items():
					sigma.append(rui - np.dot(self.P[user],self.Q[item]))
				sigma = np.array(sigma)/lengths

				for k in range(self.hid_cla):
					qk = []
					for item in items.keys():
						qk.append(self.Q[item][k])
					qk=np.array(qk)
					self.P[user][k] += self.learning_rate*(np.dot(qk,sigma) - self.lambdas*self.P[user][k])

			for item,users in self.item_user.items():
				sigma = []
				lengths = len(users)
				for user in users:
					sigma.append(self.train_data[user][item] - np.dot(self.P[user],self.Q[item]))
				sigma /= np.array(sigma)

				for k in range(self.hid_cla):
					pk = []
					for u in users:
						pk.append(self.P[u][k])
					pk = np.array(pk)
					self.Q[item][k] += self.learning_rate*(np.dot(pk,sigma) - self.lambdas*self.Q[item][k])

			self.learning_rate *= 0.9


	def __recommend(self):
		rank = {}
		for user in self.test.keys():
			local_rank={}
			for item in self.item_user.keys():
				local_rank[item] = np.dot(self.P[user],self.Q[item])
			rank[user] = local_rank
		self.rank = rank
		return self.pick()


	def __initModel(self):
		self.item_user = self.reverse_iu(self.train_data)
		self.original_P = [np.random.random(self.hid_cla) for user in range(len(self.train_data))]
		self.original_Q = [np.random.random(self.hid_cla) for user in range(len(self.item_user))]
		
		self.P = {}
		self.Q = {}
		for i,user in enumerate(self.train_data.keys()):
			self.P[user] = self.original_P[i]

		for i,item in enumerate(self.item_user.keys()):
			self.Q[item] = self.original_Q[i]



	
	def __itemPopularity(self):
		item_popularity = {}
		for user,items in self.train.items():
			for item in items:
				if item in item_popularity:
					item_popularity[item]+=1
				else:
					item_popularity[item] = 1
		self.item_popularity = item_popularity

	def calls(self,split_point = 0):
		t0 = time.time()
		self.split_data(split_point)
		t1 = time.time()
		print("split:",t1-t0)
		self.__RandomSelectNegativeSample()
		t2 = time.time()
		print("randomSelect:",t2-t1)
		self.__initModel()
		t3= time.time()
		print("init:",t3-t2)
		self.__trainLFM()

	def call(self):
		t2 = time.time()
		prediction = self.__recommend()
		print("recommend:",time.time()-t2)
		print("precision:",self.precision(prediction))
		print("recall:",self.recall(prediction))
		print("coverage:",self.coverage(prediction))
		print("popularity:",self.popularity(prediction))
		return prediction

# %%
lfm = LFM(filePath=r"moiveLens.csv",iter_num = 100,hid_cla=100,learning_rate=0.02,lambdas=0.01)
lfm.calls(split_point=0)
# Out:
# successfully load the file
# suger:
# split: 0.7814509868621826
# step=0,bili = 0.000000, ratio=1
# step=1,bili = 0.000166, ratio=1
# step=2,bili = 0.000331, ratio=1
# step=3,bili = 0.000497, ratio=1
# step=4,bili = 0.000662, ratio=1
# step=5,bili = 0.000828, ratio=1
# step=6,bili = 0.000993, ratio=1
# step=7,bili = 0.001159, ratio=1
# step=8,bili = 0.001325, ratio=1
# step=9,bili = 0.001490, ratio=1
# step=10,bili = 0.001656, ratio=1
# step=11,bili = 0.001821, ratio=1
# step=12,bili = 0.001987, ratio=1
# step=13,bili = 0.002152, ratio=1
# step=14,bili = 0.002318, ratio=1
# step=15,bili = 0.002483, ratio=1
# step=16,bili = 0.002649, ratio=1
# step=17,bili = 0.002815, ratio=1
# step=18,bili = 0.002980, ratio=1
# step=19,bili = 0.003146, ratio=1
# step=20,bili = 0.003311, ratio=1
# step=21,bili = 0.003477, ratio=1
# step=22,bili = 0.003642, ratio=1
# step=23,bili = 0.003808, ratio=1
# step=24,bili = 0.003974, ratio=1
# step=25,bili = 0.004139, ratio=1
# step=26,bili = 0.004305, ratio=1
# step=27,bili = 0.004470, ratio=1
# step=28,bili = 0.004636, ratio=1
# step=29,bili = 0.004801, ratio=1
# step=30,bili = 0.004967, ratio=1
# step=31,bili = 0.005132, ratio=1
# step=32,bili = 0.005298, ratio=1
# step=33,bili = 0.005464, ratio=1
# step=34,bili = 0.005629, ratio=1
# step=35,bili = 0.005795, ratio=1
# step=36,bili = 0.005960, ratio=1
# step=37,bili = 0.006126, ratio=1
# step=38,bili = 0.006291, ratio=1
# step=39,bili = 0.006457, ratio=1
# step=40,bili = 0.006623, ratio=1
# step=41,bili = 0.006788, ratio=1
# step=42,bili = 0.006954, ratio=1
# step=43,bili = 0.007119, ratio=1
# step=44,bili = 0.007285, ratio=1
# step=45,bili = 0.007450, ratio=1
# step=46,bili = 0.007616, ratio=1
# step=47,bili = 0.007781, ratio=1
# step=48,bili = 0.007947, ratio=1
# step=49,bili = 0.008113, ratio=1
# step=50,bili = 0.008278, ratio=1
# step=51,bili = 0.008444, ratio=1
# step=52,bili = 0.008609, ratio=1
# step=53,bili = 0.008775, ratio=1
# step=54,bili = 0.008940, ratio=1
# step=55,bili = 0.009106, ratio=1
# step=56,bili = 0.009272, ratio=1
# step=57,bili = 0.009437, ratio=1
# step=58,bili = 0.009603, ratio=1
# step=59,bili = 0.009768, ratio=1
# step=60,bili = 0.009934, ratio=1
# step=61,bili = 0.010099, ratio=1
# step=62,bili = 0.010265, ratio=1
# step=63,bili = 0.010430, ratio=1
# step=64,bili = 0.010596, ratio=1
# step=65,bili = 0.010762, ratio=1
# step=66,bili = 0.010927, ratio=1
# step=67,bili = 0.011093, ratio=1
# step=68,bili = 0.011258, ratio=1
# step=69,bili = 0.011424, ratio=1
# step=70,bili = 0.011589, ratio=1
# step=71,bili = 0.011755, ratio=1
# step=72,bili = 0.011921, ratio=1
# step=73,bili = 0.012086, ratio=1
# step=74,bili = 0.012252, ratio=1
# step=75,bili = 0.012417, ratio=1
# step=76,bili = 0.012583, ratio=1
# step=77,bili = 0.012748, ratio=1
# step=78,bili = 0.012914, ratio=1
# step=79,bili = 0.013079, ratio=1
# step=80,bili = 0.013245, ratio=1
# step=81,bili = 0.013411, ratio=1
# step=82,bili = 0.013576, ratio=1
# step=83,bili = 0.013742, ratio=1
# step=84,bili = 0.013907, ratio=1
# step=85,bili = 0.014073, ratio=1
# step=86,bili = 0.014238, ratio=1
# step=87,bili = 0.014404, ratio=1
# step=88,bili = 0.014570, ratio=1
# step=89,bili = 0.014735, ratio=1
# step=90,bili = 0.014901, ratio=1
# step=91,bili = 0.015066, ratio=1
# step=92,bili = 0.015232, ratio=1
# step=93,bili = 0.015397, ratio=1
# step=94,bili = 0.015563, ratio=1
# step=95,bili = 0.015728, ratio=1
# step=96,bili = 0.015894, ratio=1
# step=97,bili = 0.016060, ratio=1
# step=98,bili = 0.016225, ratio=1
# step=99,bili = 0.016391, ratio=1
# step=100,bili = 0.016556, ratio=1
# step=101,bili = 0.016722, ratio=1
# step=102,bili = 0.016887, ratio=1
# step=103,bili = 0.017053, ratio=1
# step=104,bili = 0.017219, ratio=1
# step=105,bili = 0.017384, ratio=1
# step=106,bili = 0.017550, ratio=1
# step=107,bili = 0.017715, ratio=1
# step=108,bili = 0.017881, ratio=1
# step=109,bili = 0.018046, ratio=1
# step=110,bili = 0.018212, ratio=1
# step=111,bili = 0.018377, ratio=1
# step=112,bili = 0.018543, ratio=1
# step=113,bili = 0.018709, ratio=1
# step=114,bili = 0.018874, ratio=1
# step=115,bili = 0.019040, ratio=1
# step=116,bili = 0.019205, ratio=1
# step=117,bili = 0.019371, ratio=1
# step=118,bili = 0.019536, ratio=1
# step=119,bili = 0.019702, ratio=1
# step=120,bili = 0.019868, ratio=1
# step=121,bili = 0.020033, ratio=1
# step=122,bili = 0.020199, ratio=1
# step=123,bili = 0.020364, ratio=1
# step=124,bili = 0.020530, ratio=1
# step=125,bili = 0.020695, ratio=1
# step=126,bili = 0.020861, ratio=1
# step=127,bili = 0.021026, ratio=1
# step=128,bili = 0.021192, ratio=1
# step=129,bili = 0.021358, ratio=1
# step=130,bili = 0.021523, ratio=1
# step=131,bili = 0.021689, ratio=1
# step=132,bili = 0.021854, ratio=1
# step=133,bili = 0.022020, ratio=1
# step=134,bili = 0.022185, ratio=1
# step=135,bili = 0.022351, ratio=1
# step=136,bili = 0.022517, ratio=1
# step=137,bili = 0.022682, ratio=1
# step=138,bili = 0.022848, ratio=1
# step=139,bili = 0.023013, ratio=1
# step=140,bili = 0.023179, ratio=1
# step=141,bili = 0.023344, ratio=1
# step=142,bili = 0.023510, ratio=1
# step=143,bili = 0.023675, ratio=1
# step=144,bili = 0.023841, ratio=1
# step=145,bili = 0.024007, ratio=1
# step=146,bili = 0.024172, ratio=1
# step=147,bili = 0.024338, ratio=1
# step=148,bili = 0.024503, ratio=1
# step=149,bili = 0.024669, ratio=1
# step=150,bili = 0.024834, ratio=1
# step=151,bili = 0.025000, ratio=1
# step=152,bili = 0.025166, ratio=1
# step=153,bili = 0.025331, ratio=1
# step=154,bili = 0.025497, ratio=1
# step=155,bili = 0.025662, ratio=1
# step=156,bili = 0.025828, ratio=1
# step=157,bili = 0.025993, ratio=1
# step=158,bili = 0.026159, ratio=1
# step=159,bili = 0.026325, ratio=1
# step=160,bili = 0.026490, ratio=1
# step=161,bili = 0.026656, ratio=1
# step=162,bili = 0.026821, ratio=1
# step=163,bili = 0.026987, ratio=1
# step=164,bili = 0.027152, ratio=1
# step=165,bili = 0.027318, ratio=1
# step=166,bili = 0.027483, ratio=1
# step=167,bili = 0.027649, ratio=1
# step=168,bili = 0.027815, ratio=1
# step=169,bili = 0.027980, ratio=1
# step=170,bili = 0.028146, ratio=1
# step=171,bili = 0.028311, ratio=1
# step=172,bili = 0.028477, ratio=1
# step=173,bili = 0.028642, ratio=1
# step=174,bili = 0.028808, ratio=1
# step=175,bili = 0.028974, ratio=1
# step=176,bili = 0.029139, ratio=1
# step=177,bili = 0.029305, ratio=1
# step=178,bili = 0.029470, ratio=1
# step=179,bili = 0.029636, ratio=1
# step=180,bili = 0.029801, ratio=1
# step=181,bili = 0.029967, ratio=1
# step=182,bili = 0.030132, ratio=1
# step=183,bili = 0.030298, ratio=1
# step=184,bili = 0.030464, ratio=1
# step=185,bili = 0.030629, ratio=1
# step=186,bili = 0.030795, ratio=1
# step=187,bili = 0.030960, ratio=1
# step=188,bili = 0.031126, ratio=1
# step=189,bili = 0.031291, ratio=1
# step=190,bili = 0.031457, ratio=1
# step=191,bili = 0.031623, ratio=1
# step=192,bili = 0.031788, ratio=1
# step=193,bili = 0.031954, ratio=1
# step=194,bili = 0.032119, ratio=1
# step=195,bili = 0.032285, ratio=1
# step=196,bili = 0.032450, ratio=1
# step=197,bili = 0.032616, ratio=1
# step=198,bili = 0.032781, ratio=1
# step=199,bili = 0.032947, ratio=1
# step=200,bili = 0.033113, ratio=1
# step=201,bili = 0.033278, ratio=1
# step=202,bili = 0.033444, ratio=1
# step=203,bili = 0.033609, ratio=1
# step=204,bili = 0.033775, ratio=1
# step=205,bili = 0.033940, ratio=1
# step=206,bili = 0.034106, ratio=1
# step=207,bili = 0.034272, ratio=1
# step=208,bili = 0.034437, ratio=1
# step=209,bili = 0.034603, ratio=1
# step=210,bili = 0.034768, ratio=1
# step=211,bili = 0.034934, ratio=1
# step=212,bili = 0.035099, ratio=1
# step=213,bili = 0.035265, ratio=1
# step=214,bili = 0.035430, ratio=1
# step=215,bili = 0.035596, ratio=1
# step=216,bili = 0.035762, ratio=1
# step=217,bili = 0.035927, ratio=1
# step=218,bili = 0.036093, ratio=1
# step=219,bili = 0.036258, ratio=1
# step=220,bili = 0.036424, ratio=1
# step=221,bili = 0.036589, ratio=1
# step=222,bili = 0.036755, ratio=1
# step=223,bili = 0.036921, ratio=1
# step=224,bili = 0.037086, ratio=1
# step=225,bili = 0.037252, ratio=1
# step=226,bili = 0.037417, ratio=1
# step=227,bili = 0.037583, ratio=1
# step=228,bili = 0.037748, ratio=1
# step=229,bili = 0.037914, ratio=1
# step=230,bili = 0.038079, ratio=1
# step=231,bili = 0.038245, ratio=1
# step=232,bili = 0.038411, ratio=1
# step=233,bili = 0.038576, ratio=1
# step=234,bili = 0.038742, ratio=1
# step=235,bili = 0.038907, ratio=1
# step=236,bili = 0.039073, ratio=1
# step=237,bili = 0.039238, ratio=1
# step=238,bili = 0.039404, ratio=1
# step=239,bili = 0.039570, ratio=1
# step=240,bili = 0.039735, ratio=1
# step=241,bili = 0.039901, ratio=1
# step=242,bili = 0.040066, ratio=1
# step=243,bili = 0.040232, ratio=1
# step=244,bili = 0.040397, ratio=1
# step=245,bili = 0.040563, ratio=1
# step=246,bili = 0.040728, ratio=1
# step=247,bili = 0.040894, ratio=1
# step=248,bili = 0.041060, ratio=1
# step=249,bili = 0.041225, ratio=1
# step=250,bili = 0.041391, ratio=1
# step=251,bili = 0.041556, ratio=1
# step=252,bili = 0.041722, ratio=1
# step=253,bili = 0.041887, ratio=1
# step=254,bili = 0.042053, ratio=1
# step=255,bili = 0.042219, ratio=1
# step=256,bili = 0.042384, ratio=1
# step=257,bili = 0.042550, ratio=1
# step=258,bili = 0.042715, ratio=1
# step=259,bili = 0.042881, ratio=1
# step=260,bili = 0.043046, ratio=1
# step=261,bili = 0.043212, ratio=1
# step=262,bili = 0.043377, ratio=1
# step=263,bili = 0.043543, ratio=1
# step=264,bili = 0.043709, ratio=1
# step=265,bili = 0.043874, ratio=1
# step=266,bili = 0.044040, ratio=1
# step=267,bili = 0.044205, ratio=1
# step=268,bili = 0.044371, ratio=1
# step=269,bili = 0.044536, ratio=1
# step=270,bili = 0.044702, ratio=1
# step=271,bili = 0.044868, ratio=1
# step=272,bili = 0.045033, ratio=1
# step=273,bili = 0.045199, ratio=1
# step=274,bili = 0.045364, ratio=1
# step=275,bili = 0.045530, ratio=1
# step=276,bili = 0.045695, ratio=1
# step=277,bili = 0.045861, ratio=1
# step=278,bili = 0.046026, ratio=1
# step=279,bili = 0.046192, ratio=1
# step=280,bili = 0.046358, ratio=1
# step=281,bili = 0.046523, ratio=1
# step=282,bili = 0.046689, ratio=1
# step=283,bili = 0.046854, ratio=1
# step=284,bili = 0.047020, ratio=1
# step=285,bili = 0.047185, ratio=1
# step=286,bili = 0.047351, ratio=1
# step=287,bili = 0.047517, ratio=1
# step=288,bili = 0.047682, ratio=1
# step=289,bili = 0.047848, ratio=1
# step=290,bili = 0.048013, ratio=1
# step=291,bili = 0.048179, ratio=1
# step=292,bili = 0.048344, ratio=1
# step=293,bili = 0.048510, ratio=1
# step=294,bili = 0.048675, ratio=1
# step=295,bili = 0.048841, ratio=1
# step=296,bili = 0.049007, ratio=1
# step=297,bili = 0.049172, ratio=1
# step=298,bili = 0.049338, ratio=1
# step=299,bili = 0.049503, ratio=1
# step=300,bili = 0.049669, ratio=1
# step=301,bili = 0.049834, ratio=1
# step=302,bili = 0.050000, ratio=1
# step=303,bili = 0.050166, ratio=1
# step=304,bili = 0.050331, ratio=1
# step=305,bili = 0.050497, ratio=1
# step=306,bili = 0.050662, ratio=1
# step=307,bili = 0.050828, ratio=1
# step=308,bili = 0.050993, ratio=1
# step=309,bili = 0.051159, ratio=1
# step=310,bili = 0.051325, ratio=1
# step=311,bili = 0.051490, ratio=1
# step=312,bili = 0.051656, ratio=1
# step=313,bili = 0.051821, ratio=1
# step=314,bili = 0.051987, ratio=1
# step=315,bili = 0.052152, ratio=1
# step=316,bili = 0.052318, ratio=1
# step=317,bili = 0.052483, ratio=1
# step=318,bili = 0.052649, ratio=1
# step=319,bili = 0.052815, ratio=1
# step=320,bili = 0.052980, ratio=1
# step=321,bili = 0.053146, ratio=1
# step=322,bili = 0.053311, ratio=1
# step=323,bili = 0.053477, ratio=1
# step=324,bili = 0.053642, ratio=1
# step=325,bili = 0.053808, ratio=1
# step=326,bili = 0.053974, ratio=1
# step=327,bili = 0.054139, ratio=1
# step=328,bili = 0.054305, ratio=1
# step=329,bili = 0.054470, ratio=1
# step=330,bili = 0.054636, ratio=1
# step=331,bili = 0.054801, ratio=1
# step=332,bili = 0.054967, ratio=1
# step=333,bili = 0.055132, ratio=1
# step=334,bili = 0.055298, ratio=1
# step=335,bili = 0.055464, ratio=1
# step=336,bili = 0.055629, ratio=1
# step=337,bili = 0.055795, ratio=1
# step=338,bili = 0.055960, ratio=1
# step=339,bili = 0.056126, ratio=1
# step=340,bili = 0.056291, ratio=1
# step=341,bili = 0.056457, ratio=1
# step=342,bili = 0.056623, ratio=1
# step=343,bili = 0.056788, ratio=1
# step=344,bili = 0.056954, ratio=1
# step=345,bili = 0.057119, ratio=1
# step=346,bili = 0.057285, ratio=1
# step=347,bili = 0.057450, ratio=1
# step=348,bili = 0.057616, ratio=1
# step=349,bili = 0.057781, ratio=1
# step=350,bili = 0.057947, ratio=1
# step=351,bili = 0.058113, ratio=1
# step=352,bili = 0.058278, ratio=1
# step=353,bili = 0.058444, ratio=1
# step=354,bili = 0.058609, ratio=1
# step=355,bili = 0.058775, ratio=1
# step=356,bili = 0.058940, ratio=1
# step=357,bili = 0.059106, ratio=1
# step=358,bili = 0.059272, ratio=1
# step=359,bili = 0.059437, ratio=1
# step=360,bili = 0.059603, ratio=1
# step=361,bili = 0.059768, ratio=1
# step=362,bili = 0.059934, ratio=1
# step=363,bili = 0.060099, ratio=1
# step=364,bili = 0.060265, ratio=1
# step=365,bili = 0.060430, ratio=1
# step=366,bili = 0.060596, ratio=1
# step=367,bili = 0.060762, ratio=1
# step=368,bili = 0.060927, ratio=1
# step=369,bili = 0.061093, ratio=1
# step=370,bili = 0.061258, ratio=1
# step=371,bili = 0.061424, ratio=1
# step=372,bili = 0.061589, ratio=1
# step=373,bili = 0.061755, ratio=1
# step=374,bili = 0.061921, ratio=1
# step=375,bili = 0.062086, ratio=1
# step=376,bili = 0.062252, ratio=1
# step=377,bili = 0.062417, ratio=1
# step=378,bili = 0.062583, ratio=1
# step=379,bili = 0.062748, ratio=1
# step=380,bili = 0.062914, ratio=1
# step=381,bili = 0.063079, ratio=1
# step=382,bili = 0.063245, ratio=1
# step=383,bili = 0.063411, ratio=1
# step=384,bili = 0.063576, ratio=1
# step=385,bili = 0.063742, ratio=1
# step=386,bili = 0.063907, ratio=1
# step=387,bili = 0.064073, ratio=1
# step=388,bili = 0.064238, ratio=1
# step=389,bili = 0.064404, ratio=1
# step=390,bili = 0.064570, ratio=1
# step=391,bili = 0.064735, ratio=1
# step=392,bili = 0.064901, ratio=1
# step=393,bili = 0.065066, ratio=1
# step=394,bili = 0.065232, ratio=1
# step=395,bili = 0.065397, ratio=1
# step=396,bili = 0.065563, ratio=1
# step=397,bili = 0.065728, ratio=1
# step=398,bili = 0.065894, ratio=1
# step=399,bili = 0.066060, ratio=1
# step=400,bili = 0.066225, ratio=1
# step=401,bili = 0.066391, ratio=1
# step=402,bili = 0.066556, ratio=1
# step=403,bili = 0.066722, ratio=1
# step=404,bili = 0.066887, ratio=1
# step=405,bili = 0.067053, ratio=1
# step=406,bili = 0.067219, ratio=1
# step=407,bili = 0.067384, ratio=1
# step=408,bili = 0.067550, ratio=1
# step=409,bili = 0.067715, ratio=1
# step=410,bili = 0.067881, ratio=1
# step=411,bili = 0.068046, ratio=1
# step=412,bili = 0.068212, ratio=1
# step=413,bili = 0.068377, ratio=1
# step=414,bili = 0.068543, ratio=1
# step=415,bili = 0.068709, ratio=1
# step=416,bili = 0.068874, ratio=1
# step=417,bili = 0.069040, ratio=1
# step=418,bili = 0.069205, ratio=1
# step=419,bili = 0.069371, ratio=1
# step=420,bili = 0.069536, ratio=1
# step=421,bili = 0.069702, ratio=1
# step=422,bili = 0.069868, ratio=1
# step=423,bili = 0.070033, ratio=1
# step=424,bili = 0.070199, ratio=1
# step=425,bili = 0.070364, ratio=1
# step=426,bili = 0.070530, ratio=1
# step=427,bili = 0.070695, ratio=1
# step=428,bili = 0.070861, ratio=1
# step=429,bili = 0.071026, ratio=1
# step=430,bili = 0.071192, ratio=1
# step=431,bili = 0.071358, ratio=1
# step=432,bili = 0.071523, ratio=1
# step=433,bili = 0.071689, ratio=1
# step=434,bili = 0.071854, ratio=1
# step=435,bili = 0.072020, ratio=1
# step=436,bili = 0.072185, ratio=1
# step=437,bili = 0.072351, ratio=1
# step=438,bili = 0.072517, ratio=1
# step=439,bili = 0.072682, ratio=1
# step=440,bili = 0.072848, ratio=1
# step=441,bili = 0.073013, ratio=1
# step=442,bili = 0.073179, ratio=1
# step=443,bili = 0.073344, ratio=1
# step=444,bili = 0.073510, ratio=1
# step=445,bili = 0.073675, ratio=1
# step=446,bili = 0.073841, ratio=1
# step=447,bili = 0.074007, ratio=1
# step=448,bili = 0.074172, ratio=1
# step=449,bili = 0.074338, ratio=1
# step=450,bili = 0.074503, ratio=1
# step=451,bili = 0.074669, ratio=1
# step=452,bili = 0.074834, ratio=1
# step=453,bili = 0.075000, ratio=1
# step=454,bili = 0.075166, ratio=1
# step=455,bili = 0.075331, ratio=1
# step=456,bili = 0.075497, ratio=1
# step=457,bili = 0.075662, ratio=1
# step=458,bili = 0.075828, ratio=1
# step=459,bili = 0.075993, ratio=0
# step=460,bili = 0.076159, ratio=1
# step=461,bili = 0.076325, ratio=1
# step=462,bili = 0.076490, ratio=1
# step=463,bili = 0.076656, ratio=1
# step=464,bili = 0.076821, ratio=1
# step=465,bili = 0.076987, ratio=1
# step=466,bili = 0.077152, ratio=1
# step=467,bili = 0.077318, ratio=1
# step=468,bili = 0.077483, ratio=1
# step=469,bili = 0.077649, ratio=1
# step=470,bili = 0.077815, ratio=1
# step=471,bili = 0.077980, ratio=1
# step=472,bili = 0.078146, ratio=1
# step=473,bili = 0.078311, ratio=1
# step=474,bili = 0.078477, ratio=1
# step=475,bili = 0.078642, ratio=1
# step=476,bili = 0.078808, ratio=1
# step=477,bili = 0.078974, ratio=1
# step=478,bili = 0.079139, ratio=1
# step=479,bili = 0.079305, ratio=1
# step=480,bili = 0.079470, ratio=1
# step=481,bili = 0.079636, ratio=1
# step=482,bili = 0.079801, ratio=1
# step=483,bili = 0.079967, ratio=1
# step=484,bili = 0.080132, ratio=1
# step=485,bili = 0.080298, ratio=1
# step=486,bili = 0.080464, ratio=1
# step=487,bili = 0.080629, ratio=1
# step=488,bili = 0.080795, ratio=1
# step=489,bili = 0.080960, ratio=1
# step=490,bili = 0.081126, ratio=1
# step=491,bili = 0.081291, ratio=1
# step=492,bili = 0.081457, ratio=1
# step=493,bili = 0.081623, ratio=1
# step=494,bili = 0.081788, ratio=1
# step=495,bili = 0.081954, ratio=1
# step=496,bili = 0.082119, ratio=1
# step=497,bili = 0.082285, ratio=1
# step=498,bili = 0.082450, ratio=1
# step=499,bili = 0.082616, ratio=1
# step=500,bili = 0.082781, ratio=1
# step=501,bili = 0.082947, ratio=1
# step=502,bili = 0.083113, ratio=1
# step=503,bili = 0.083278, ratio=1
# step=504,bili = 0.083444, ratio=1
# step=505,bili = 0.083609, ratio=1
# step=506,bili = 0.083775, ratio=1
# step=507,bili = 0.083940, ratio=1
# step=508,bili = 0.084106, ratio=1
# step=509,bili = 0.084272, ratio=1
# step=510,bili = 0.084437, ratio=1
# step=511,bili = 0.084603, ratio=1
# step=512,bili = 0.084768, ratio=1
# step=513,bili = 0.084934, ratio=1
# step=514,bili = 0.085099, ratio=1
# step=515,bili = 0.085265, ratio=1
# step=516,bili = 0.085430, ratio=1
# step=517,bili = 0.085596, ratio=1
# step=518,bili = 0.085762, ratio=1
# step=519,bili = 0.085927, ratio=1
# step=520,bili = 0.086093, ratio=1
# step=521,bili = 0.086258, ratio=1
# step=522,bili = 0.086424, ratio=1
# step=523,bili = 0.086589, ratio=1
# step=524,bili = 0.086755, ratio=1
# step=525,bili = 0.086921, ratio=1
# step=526,bili = 0.087086, ratio=1
# step=527,bili = 0.087252, ratio=1
# step=528,bili = 0.087417, ratio=1
# step=529,bili = 0.087583, ratio=1
# step=530,bili = 0.087748, ratio=1
# step=531,bili = 0.087914, ratio=1
# step=532,bili = 0.088079, ratio=1
# step=533,bili = 0.088245, ratio=1
# step=534,bili = 0.088411, ratio=1
# step=535,bili = 0.088576, ratio=1
# step=536,bili = 0.088742, ratio=1
# step=537,bili = 0.088907, ratio=1
# step=538,bili = 0.089073, ratio=1
# step=539,bili = 0.089238, ratio=1
# step=540,bili = 0.089404, ratio=1
# step=541,bili = 0.089570, ratio=1
# step=542,bili = 0.089735, ratio=1
# step=543,bili = 0.089901, ratio=1
# step=544,bili = 0.090066, ratio=1
# step=545,bili = 0.090232, ratio=1
# step=546,bili = 0.090397, ratio=1
# step=547,bili = 0.090563, ratio=1
# step=548,bili = 0.090728, ratio=1
# step=549,bili = 0.090894, ratio=1
# step=550,bili = 0.091060, ratio=1
# step=551,bili = 0.091225, ratio=1
# step=552,bili = 0.091391, ratio=1
# step=553,bili = 0.091556, ratio=1
# step=554,bili = 0.091722, ratio=1
# step=555,bili = 0.091887, ratio=1
# step=556,bili = 0.092053, ratio=1
# step=557,bili = 0.092219, ratio=1
# step=558,bili = 0.092384, ratio=1
# step=559,bili = 0.092550, ratio=1
# step=560,bili = 0.092715, ratio=1
# step=561,bili = 0.092881, ratio=1
# step=562,bili = 0.093046, ratio=1
# step=563,bili = 0.093212, ratio=1
# step=564,bili = 0.093377, ratio=1
# step=565,bili = 0.093543, ratio=1
# step=566,bili = 0.093709, ratio=1
# step=567,bili = 0.093874, ratio=1
# step=568,bili = 0.094040, ratio=1
# step=569,bili = 0.094205, ratio=1
# step=570,bili = 0.094371, ratio=1
# step=571,bili = 0.094536, ratio=1
# step=572,bili = 0.094702, ratio=1
# step=573,bili = 0.094868, ratio=1
# step=574,bili = 0.095033, ratio=1
# step=575,bili = 0.095199, ratio=1
# step=576,bili = 0.095364, ratio=1
# step=577,bili = 0.095530, ratio=1
# step=578,bili = 0.095695, ratio=1
# step=579,bili = 0.095861, ratio=1
# step=580,bili = 0.096026, ratio=1
# step=581,bili = 0.096192, ratio=1
# step=582,bili = 0.096358, ratio=1
# step=583,bili = 0.096523, ratio=1
# step=584,bili = 0.096689, ratio=1
# step=585,bili = 0.096854, ratio=1
# step=586,bili = 0.097020, ratio=1
# step=587,bili = 0.097185, ratio=1
# step=588,bili = 0.097351, ratio=1
# step=589,bili = 0.097517, ratio=1
# step=590,bili = 0.097682, ratio=1
# step=591,bili = 0.097848, ratio=1
# step=592,bili = 0.098013, ratio=1
# step=593,bili = 0.098179, ratio=1
# step=594,bili = 0.098344, ratio=1
# step=595,bili = 0.098510, ratio=1
# step=596,bili = 0.098675, ratio=1
# step=597,bili = 0.098841, ratio=1
# step=598,bili = 0.099007, ratio=1
# step=599,bili = 0.099172, ratio=1
# step=600,bili = 0.099338, ratio=1
# step=601,bili = 0.099503, ratio=1
# step=602,bili = 0.099669, ratio=1
# step=603,bili = 0.099834, ratio=1
# step=604,bili = 0.100000, ratio=1
# step=605,bili = 0.100166, ratio=1
# step=606,bili = 0.100331, ratio=1
# step=607,bili = 0.100497, ratio=1
# step=608,bili = 0.100662, ratio=1
# step=609,bili = 0.100828, ratio=1
# step=610,bili = 0.100993, ratio=1
# step=611,bili = 0.101159, ratio=1
# step=612,bili = 0.101325, ratio=1
# step=613,bili = 0.101490, ratio=1
# step=614,bili = 0.101656, ratio=1
# step=615,bili = 0.101821, ratio=1
# step=616,bili = 0.101987, ratio=1
# step=617,bili = 0.102152, ratio=1
# step=618,bili = 0.102318, ratio=1
# step=619,bili = 0.102483, ratio=1
# step=620,bili = 0.102649, ratio=1
# step=621,bili = 0.102815, ratio=1
# step=622,bili = 0.102980, ratio=1
# step=623,bili = 0.103146, ratio=1
# step=624,bili = 0.103311, ratio=1
# step=625,bili = 0.103477, ratio=1
# step=626,bili = 0.103642, ratio=1
# step=627,bili = 0.103808, ratio=1
# step=628,bili = 0.103974, ratio=1
# step=629,bili = 0.104139, ratio=1
# step=630,bili = 0.104305, ratio=1
# step=631,bili = 0.104470, ratio=1
# step=632,bili = 0.104636, ratio=1
# step=633,bili = 0.104801, ratio=1
# step=634,bili = 0.104967, ratio=1
# step=635,bili = 0.105132, ratio=1
# step=636,bili = 0.105298, ratio=1
# step=637,bili = 0.105464, ratio=1
# step=638,bili = 0.105629, ratio=1
# step=639,bili = 0.105795, ratio=1
# step=640,bili = 0.105960, ratio=1
# step=641,bili = 0.106126, ratio=1
# step=642,bili = 0.106291, ratio=1
# step=643,bili = 0.106457, ratio=1
# step=644,bili = 0.106623, ratio=1
# step=645,bili = 0.106788, ratio=1
# step=646,bili = 0.106954, ratio=1
# step=647,bili = 0.107119, ratio=1
# step=648,bili = 0.107285, ratio=1
# step=649,bili = 0.107450, ratio=1
# step=650,bili = 0.107616, ratio=1
# step=651,bili = 0.107781, ratio=1
# step=652,bili = 0.107947, ratio=1
# step=653,bili = 0.108113, ratio=1
# step=654,bili = 0.108278, ratio=1
# step=655,bili = 0.108444, ratio=1
# step=656,bili = 0.108609, ratio=1
# step=657,bili = 0.108775, ratio=1
# step=658,bili = 0.108940, ratio=1
# step=659,bili = 0.109106, ratio=1
# step=660,bili = 0.109272, ratio=1
# step=661,bili = 0.109437, ratio=1
# step=662,bili = 0.109603, ratio=1
# step=663,bili = 0.109768, ratio=1
# step=664,bili = 0.109934, ratio=1
# step=665,bili = 0.110099, ratio=1
# step=666,bili = 0.110265, ratio=1
# step=667,bili = 0.110430, ratio=1
# step=668,bili = 0.110596, ratio=1
# step=669,bili = 0.110762, ratio=1
# step=670,bili = 0.110927, ratio=1
# step=671,bili = 0.111093, ratio=1
# step=672,bili = 0.111258, ratio=1
# step=673,bili = 0.111424, ratio=1
# step=674,bili = 0.111589, ratio=1
# step=675,bili = 0.111755, ratio=1
# step=676,bili = 0.111921, ratio=1
# step=677,bili = 0.112086, ratio=1
# step=678,bili = 0.112252, ratio=1
# step=679,bili = 0.112417, ratio=1
# step=680,bili = 0.112583, ratio=1
# step=681,bili = 0.112748, ratio=1
# step=682,bili = 0.112914, ratio=1
# step=683,bili = 0.113079, ratio=1
# step=684,bili = 0.113245, ratio=1
# step=685,bili = 0.113411, ratio=1
# step=686,bili = 0.113576, ratio=1
# step=687,bili = 0.113742, ratio=1
# step=688,bili = 0.113907, ratio=1
# step=689,bili = 0.114073, ratio=1
# step=690,bili = 0.114238, ratio=1
# step=691,bili = 0.114404, ratio=1
# step=692,bili = 0.114570, ratio=1
# step=693,bili = 0.114735, ratio=1
# step=694,bili = 0.114901, ratio=1
# step=695,bili = 0.115066, ratio=1
# step=696,bili = 0.115232, ratio=1
# step=697,bili = 0.115397, ratio=1
# step=698,bili = 0.115563, ratio=1
# step=699,bili = 0.115728, ratio=1
# step=700,bili = 0.115894, ratio=1
# step=701,bili = 0.116060, ratio=1
# step=702,bili = 0.116225, ratio=1
# step=703,bili = 0.116391, ratio=1
# step=704,bili = 0.116556, ratio=1
# step=705,bili = 0.116722, ratio=1
# step=706,bili = 0.116887, ratio=1
# step=707,bili = 0.117053, ratio=1
# step=708,bili = 0.117219, ratio=1
# step=709,bili = 0.117384, ratio=1
# step=710,bili = 0.117550, ratio=1
# step=711,bili = 0.117715, ratio=1
# step=712,bili = 0.117881, ratio=1
# step=713,bili = 0.118046, ratio=1
# step=714,bili = 0.118212, ratio=1
# step=715,bili = 0.118377, ratio=1
# step=716,bili = 0.118543, ratio=1
# step=717,bili = 0.118709, ratio=1
# step=718,bili = 0.118874, ratio=1
# step=719,bili = 0.119040, ratio=1
# step=720,bili = 0.119205, ratio=1
# step=721,bili = 0.119371, ratio=1
# step=722,bili = 0.119536, ratio=1
# step=723,bili = 0.119702, ratio=1
# step=724,bili = 0.119868, ratio=1
# step=725,bili = 0.120033, ratio=1
# step=726,bili = 0.120199, ratio=1
# step=727,bili = 0.120364, ratio=1
# step=728,bili = 0.120530, ratio=1
# step=729,bili = 0.120695, ratio=1
# step=730,bili = 0.120861, ratio=1
# step=731,bili = 0.121026, ratio=1
# step=732,bili = 0.121192, ratio=1
# step=733,bili = 0.121358, ratio=1
# step=734,bili = 0.121523, ratio=1
# step=735,bili = 0.121689, ratio=1
# step=736,bili = 0.121854, ratio=1
# step=737,bili = 0.122020, ratio=1
# step=738,bili = 0.122185, ratio=1
# step=739,bili = 0.122351, ratio=1
# step=740,bili = 0.122517, ratio=1
# step=741,bili = 0.122682, ratio=1
# step=742,bili = 0.122848, ratio=1
# step=743,bili = 0.123013, ratio=1
# step=744,bili = 0.123179, ratio=1
# step=745,bili = 0.123344, ratio=1
# step=746,bili = 0.123510, ratio=1
# step=747,bili = 0.123675, ratio=1
# step=748,bili = 0.123841, ratio=1
# step=749,bili = 0.124007, ratio=1
# step=750,bili = 0.124172, ratio=1
# step=751,bili = 0.124338, ratio=1
# step=752,bili = 0.124503, ratio=1
# step=753,bili = 0.124669, ratio=1
# step=754,bili = 0.124834, ratio=1
# step=755,bili = 0.125000, ratio=1
# step=756,bili = 0.125166, ratio=1
# step=757,bili = 0.125331, ratio=1
# step=758,bili = 0.125497, ratio=1
# step=759,bili = 0.125662, ratio=1
# step=760,bili = 0.125828, ratio=1
# step=761,bili = 0.125993, ratio=1
# step=762,bili = 0.126159, ratio=1
# step=763,bili = 0.126325, ratio=1
# step=764,bili = 0.126490, ratio=1
# step=765,bili = 0.126656, ratio=1
# step=766,bili = 0.126821, ratio=1
# step=767,bili = 0.126987, ratio=1
# step=768,bili = 0.127152, ratio=1
# step=769,bili = 0.127318, ratio=1
# step=770,bili = 0.127483, ratio=1
# step=771,bili = 0.127649, ratio=1
# step=772,bili = 0.127815, ratio=1
# step=773,bili = 0.127980, ratio=1
# step=774,bili = 0.128146, ratio=1
# step=775,bili = 0.128311, ratio=1
# step=776,bili = 0.128477, ratio=1
# step=777,bili = 0.128642, ratio=1
# step=778,bili = 0.128808, ratio=1
# step=779,bili = 0.128974, ratio=1
# step=780,bili = 0.129139, ratio=1
# step=781,bili = 0.129305, ratio=1
# step=782,bili = 0.129470, ratio=1
# step=783,bili = 0.129636, ratio=1
# step=784,bili = 0.129801, ratio=1
# step=785,bili = 0.129967, ratio=1
# step=786,bili = 0.130132, ratio=1
# step=787,bili = 0.130298, ratio=1
# step=788,bili = 0.130464, ratio=1
# step=789,bili = 0.130629, ratio=1
# step=790,bili = 0.130795, ratio=1
# step=791,bili = 0.130960, ratio=1
# step=792,bili = 0.131126, ratio=1
# step=793,bili = 0.131291, ratio=1
# step=794,bili = 0.131457, ratio=1
# step=795,bili = 0.131623, ratio=1
# step=796,bili = 0.131788, ratio=1
# step=797,bili = 0.131954, ratio=1
# step=798,bili = 0.132119, ratio=1
# step=799,bili = 0.132285, ratio=1
# step=800,bili = 0.132450, ratio=1
# step=801,bili = 0.132616, ratio=1
# step=802,bili = 0.132781, ratio=1
# step=803,bili = 0.132947, ratio=1
# step=804,bili = 0.133113, ratio=1
# step=805,bili = 0.133278, ratio=1
# step=806,bili = 0.133444, ratio=1
# step=807,bili = 0.133609, ratio=1
# step=808,bili = 0.133775, ratio=1
# step=809,bili = 0.133940, ratio=1
# step=810,bili = 0.134106, ratio=1
# step=811,bili = 0.134272, ratio=1
# step=812,bili = 0.134437, ratio=1
# step=813,bili = 0.134603, ratio=1
# step=814,bili = 0.134768, ratio=1
# step=815,bili = 0.134934, ratio=1
# step=816,bili = 0.135099, ratio=1
# step=817,bili = 0.135265, ratio=1
# step=818,bili = 0.135430, ratio=1
# step=819,bili = 0.135596, ratio=1
# step=820,bili = 0.135762, ratio=1
# step=821,bili = 0.135927, ratio=1
# step=822,bili = 0.136093, ratio=1
# step=823,bili = 0.136258, ratio=1
# step=824,bili = 0.136424, ratio=1
# step=825,bili = 0.136589, ratio=1
# step=826,bili = 0.136755, ratio=1
# step=827,bili = 0.136921, ratio=1
# step=828,bili = 0.137086, ratio=1
# step=829,bili = 0.137252, ratio=1
# step=830,bili = 0.137417, ratio=1
# step=831,bili = 0.137583, ratio=1
# step=832,bili = 0.137748, ratio=1
# step=833,bili = 0.137914, ratio=1
# step=834,bili = 0.138079, ratio=1
# step=835,bili = 0.138245, ratio=1
# step=836,bili = 0.138411, ratio=1
# step=837,bili = 0.138576, ratio=1
# step=838,bili = 0.138742, ratio=1
# step=839,bili = 0.138907, ratio=1
# step=840,bili = 0.139073, ratio=1
# step=841,bili = 0.139238, ratio=1
# step=842,bili = 0.139404, ratio=1
# step=843,bili = 0.139570, ratio=1
# step=844,bili = 0.139735, ratio=1
# step=845,bili = 0.139901, ratio=1
# step=846,bili = 0.140066, ratio=1
# step=847,bili = 0.140232, ratio=1
# step=848,bili = 0.140397, ratio=1
# step=849,bili = 0.140563, ratio=1
# step=850,bili = 0.140728, ratio=1
# step=851,bili = 0.140894, ratio=1
# step=852,bili = 0.141060, ratio=1
# step=853,bili = 0.141225, ratio=1
# step=854,bili = 0.141391, ratio=1
# step=855,bili = 0.141556, ratio=1
# step=856,bili = 0.141722, ratio=1
# step=857,bili = 0.141887, ratio=1
# step=858,bili = 0.142053, ratio=1
# step=859,bili = 0.142219, ratio=1
# step=860,bili = 0.142384, ratio=1
# step=861,bili = 0.142550, ratio=1
# step=862,bili = 0.142715, ratio=1
# step=863,bili = 0.142881, ratio=1
# step=864,bili = 0.143046, ratio=1
# step=865,bili = 0.143212, ratio=1
# step=866,bili = 0.143377, ratio=1
# step=867,bili = 0.143543, ratio=1
# step=868,bili = 0.143709, ratio=1
# step=869,bili = 0.143874, ratio=1
# step=870,bili = 0.144040, ratio=1
# step=871,bili = 0.144205, ratio=1
# step=872,bili = 0.144371, ratio=1
# step=873,bili = 0.144536, ratio=1
# step=874,bili = 0.144702, ratio=1
# step=875,bili = 0.144868, ratio=1
# step=876,bili = 0.145033, ratio=1
# step=877,bili = 0.145199, ratio=1
# step=878,bili = 0.145364, ratio=1
# step=879,bili = 0.145530, ratio=1
# step=880,bili = 0.145695, ratio=1
# step=881,bili = 0.145861, ratio=1
# step=882,bili = 0.146026, ratio=1
# step=883,bili = 0.146192, ratio=1
# step=884,bili = 0.146358, ratio=1
# step=885,bili = 0.146523, ratio=1
# step=886,bili = 0.146689, ratio=1
# step=887,bili = 0.146854, ratio=1
# step=888,bili = 0.147020, ratio=1
# step=889,bili = 0.147185, ratio=1
# step=890,bili = 0.147351, ratio=1
# step=891,bili = 0.147517, ratio=1
# step=892,bili = 0.147682, ratio=1
# step=893,bili = 0.147848, ratio=1
# step=894,bili = 0.148013, ratio=1
# step=895,bili = 0.148179, ratio=1
# step=896,bili = 0.148344, ratio=1
# step=897,bili = 0.148510, ratio=1
# step=898,bili = 0.148675, ratio=1
# step=899,bili = 0.148841, ratio=1
# step=900,bili = 0.149007, ratio=1
# step=901,bili = 0.149172, ratio=1
# step=902,bili = 0.149338, ratio=1
# step=903,bili = 0.149503, ratio=1
# step=904,bili = 0.149669, ratio=1
# step=905,bili = 0.149834, ratio=1
# step=906,bili = 0.150000, ratio=1
# step=907,bili = 0.150166, ratio=1
# step=908,bili = 0.150331, ratio=1
# step=909,bili = 0.150497, ratio=1
# step=910,bili = 0.150662, ratio=1
# step=911,bili = 0.150828, ratio=1
# step=912,bili = 0.150993, ratio=1
# step=913,bili = 0.151159, ratio=1
# step=914,bili = 0.151325, ratio=1
# step=915,bili = 0.151490, ratio=1
# step=916,bili = 0.151656, ratio=1
# step=917,bili = 0.151821, ratio=1
# step=918,bili = 0.151987, ratio=1
# step=919,bili = 0.152152, ratio=1
# step=920,bili = 0.152318, ratio=1
# step=921,bili = 0.152483, ratio=1
# step=922,bili = 0.152649, ratio=1
# step=923,bili = 0.152815, ratio=1
# step=924,bili = 0.152980, ratio=1
# step=925,bili = 0.153146, ratio=1
# step=926,bili = 0.153311, ratio=1
# step=927,bili = 0.153477, ratio=1
# step=928,bili = 0.153642, ratio=1
# step=929,bili = 0.153808, ratio=1
# step=930,bili = 0.153974, ratio=1
# step=931,bili = 0.154139, ratio=1
# step=932,bili = 0.154305, ratio=1
# step=933,bili = 0.154470, ratio=1
# step=934,bili = 0.154636, ratio=1
# step=935,bili = 0.154801, ratio=1
# step=936,bili = 0.154967, ratio=1
# step=937,bili = 0.155132, ratio=1
# step=938,bili = 0.155298, ratio=1
# step=939,bili = 0.155464, ratio=1
# step=940,bili = 0.155629, ratio=1
# step=941,bili = 0.155795, ratio=1
# step=942,bili = 0.155960, ratio=1
# step=943,bili = 0.156126, ratio=1
# step=944,bili = 0.156291, ratio=1
# step=945,bili = 0.156457, ratio=1
# step=946,bili = 0.156623, ratio=1
# step=947,bili = 0.156788, ratio=1
# step=948,bili = 0.156954, ratio=1
# step=949,bili = 0.157119, ratio=1
# step=950,bili = 0.157285, ratio=1
# step=951,bili = 0.157450, ratio=1
# step=952,bili = 0.157616, ratio=1
# step=953,bili = 0.157781, ratio=1
# step=954,bili = 0.157947, ratio=1
# step=955,bili = 0.158113, ratio=1
# step=956,bili = 0.158278, ratio=1
# step=957,bili = 0.158444, ratio=1
# step=958,bili = 0.158609, ratio=1
# step=959,bili = 0.158775, ratio=1
# step=960,bili = 0.158940, ratio=1
# step=961,bili = 0.159106, ratio=1
# step=962,bili = 0.159272, ratio=1
# step=963,bili = 0.159437, ratio=1
# step=964,bili = 0.159603, ratio=1
# step=965,bili = 0.159768, ratio=1
# step=966,bili = 0.159934, ratio=1
# step=967,bili = 0.160099, ratio=1
# step=968,bili = 0.160265, ratio=1
# step=969,bili = 0.160430, ratio=1
# step=970,bili = 0.160596, ratio=1
# step=971,bili = 0.160762, ratio=1
# step=972,bili = 0.160927, ratio=1
# step=973,bili = 0.161093, ratio=1
# step=974,bili = 0.161258, ratio=1
# step=975,bili = 0.161424, ratio=1
# step=976,bili = 0.161589, ratio=1
# step=977,bili = 0.161755, ratio=1
# step=978,bili = 0.161921, ratio=1
# step=979,bili = 0.162086, ratio=1
# step=980,bili = 0.162252, ratio=1
# step=981,bili = 0.162417, ratio=1
# step=982,bili = 0.162583, ratio=1
# step=983,bili = 0.162748, ratio=1
# step=984,bili = 0.162914, ratio=1
# step=985,bili = 0.163079, ratio=1
# step=986,bili = 0.163245, ratio=1
# step=987,bili = 0.163411, ratio=1
# step=988,bili = 0.163576, ratio=1
# step=989,bili = 0.163742, ratio=1
# step=990,bili = 0.163907, ratio=1
# step=991,bili = 0.164073, ratio=1
# step=992,bili = 0.164238, ratio=1
# step=993,bili = 0.164404, ratio=1
# step=994,bili = 0.164570, ratio=1
# step=995,bili = 0.164735, ratio=1
# step=996,bili = 0.164901, ratio=1
# step=997,bili = 0.165066, ratio=1
# step=998,bili = 0.165232, ratio=1
# step=999,bili = 0.165397, ratio=1
# step=1000,bili = 0.165563, ratio=1
# step=1001,bili = 0.165728, ratio=1
# step=1002,bili = 0.165894, ratio=1
# step=1003,bili = 0.166060, ratio=1
# step=1004,bili = 0.166225, ratio=1
# step=1005,bili = 0.166391, ratio=1
# step=1006,bili = 0.166556, ratio=1
# step=1007,bili = 0.166722, ratio=1
# step=1008,bili = 0.166887, ratio=1
# step=1009,bili = 0.167053, ratio=1
# step=1010,bili = 0.167219, ratio=1
# step=1011,bili = 0.167384, ratio=1
# step=1012,bili = 0.167550, ratio=1
# step=1013,bili = 0.167715, ratio=1
# step=1014,bili = 0.167881, ratio=1
# step=1015,bili = 0.168046, ratio=1
# step=1016,bili = 0.168212, ratio=1
# step=1017,bili = 0.168377, ratio=1
# step=1018,bili = 0.168543, ratio=1
# step=1019,bili = 0.168709, ratio=1
# step=1020,bili = 0.168874, ratio=1
# step=1021,bili = 0.169040, ratio=1
# step=1022,bili = 0.169205, ratio=1
# step=1023,bili = 0.169371, ratio=1
# step=1024,bili = 0.169536, ratio=1
# step=1025,bili = 0.169702, ratio=1
# step=1026,bili = 0.169868, ratio=1
# step=1027,bili = 0.170033, ratio=1
# step=1028,bili = 0.170199, ratio=1
# step=1029,bili = 0.170364, ratio=1
# step=1030,bili = 0.170530, ratio=1
# step=1031,bili = 0.170695, ratio=1
# step=1032,bili = 0.170861, ratio=1
# step=1033,bili = 0.171026, ratio=1
# step=1034,bili = 0.171192, ratio=1
# step=1035,bili = 0.171358, ratio=1
# step=1036,bili = 0.171523, ratio=1
# step=1037,bili = 0.171689, ratio=1
# step=1038,bili = 0.171854, ratio=1
# step=1039,bili = 0.172020, ratio=1
# step=1040,bili = 0.172185, ratio=1
# step=1041,bili = 0.172351, ratio=1
# step=1042,bili = 0.172517, ratio=1
# step=1043,bili = 0.172682, ratio=1
# step=1044,bili = 0.172848, ratio=1
# step=1045,bili = 0.173013, ratio=1
# step=1046,bili = 0.173179, ratio=1
# step=1047,bili = 0.173344, ratio=1
# step=1048,bili = 0.173510, ratio=1
# step=1049,bili = 0.173675, ratio=1
# step=1050,bili = 0.173841, ratio=1
# step=1051,bili = 0.174007, ratio=1
# step=1052,bili = 0.174172, ratio=1
# step=1053,bili = 0.174338, ratio=1
# step=1054,bili = 0.174503, ratio=1
# step=1055,bili = 0.174669, ratio=1
# step=1056,bili = 0.174834, ratio=1
# step=1057,bili = 0.175000, ratio=1
# step=1058,bili = 0.175166, ratio=1
# step=1059,bili = 0.175331, ratio=1
# step=1060,bili = 0.175497, ratio=1
# step=1061,bili = 0.175662, ratio=1
# step=1062,bili = 0.175828, ratio=1
# step=1063,bili = 0.175993, ratio=1
# step=1064,bili = 0.176159, ratio=1
# step=1065,bili = 0.176325, ratio=1
# step=1066,bili = 0.176490, ratio=1
# step=1067,bili = 0.176656, ratio=1
# step=1068,bili = 0.176821, ratio=1
# step=1069,bili = 0.176987, ratio=1
# step=1070,bili = 0.177152, ratio=1
# step=1071,bili = 0.177318, ratio=1
# step=1072,bili = 0.177483, ratio=1
# step=1073,bili = 0.177649, ratio=1
# step=1074,bili = 0.177815, ratio=1
# step=1075,bili = 0.177980, ratio=1
# step=1076,bili = 0.178146, ratio=1
# step=1077,bili = 0.178311, ratio=1
# step=1078,bili = 0.178477, ratio=1
# step=1079,bili = 0.178642, ratio=1
# step=1080,bili = 0.178808, ratio=1
# step=1081,bili = 0.178974, ratio=1
# step=1082,bili = 0.179139, ratio=1
# step=1083,bili = 0.179305, ratio=1
# step=1084,bili = 0.179470, ratio=1
# step=1085,bili = 0.179636, ratio=1
# step=1086,bili = 0.179801, ratio=1
# step=1087,bili = 0.179967, ratio=1
# step=1088,bili = 0.180132, ratio=1
# step=1089,bili = 0.180298, ratio=1
# step=1090,bili = 0.180464, ratio=1
# step=1091,bili = 0.180629, ratio=1
# step=1092,bili = 0.180795, ratio=1
# step=1093,bili = 0.180960, ratio=1
# step=1094,bili = 0.181126, ratio=1
# step=1095,bili = 0.181291, ratio=1
# step=1096,bili = 0.181457, ratio=1
# step=1097,bili = 0.181623, ratio=1
# step=1098,bili = 0.181788, ratio=1
# step=1099,bili = 0.181954, ratio=1
# step=1100,bili = 0.182119, ratio=1
# step=1101,bili = 0.182285, ratio=1
# step=1102,bili = 0.182450, ratio=1
# step=1103,bili = 0.182616, ratio=1
# step=1104,bili = 0.182781, ratio=1
# step=1105,bili = 0.182947, ratio=1
# step=1106,bili = 0.183113, ratio=1
# step=1107,bili = 0.183278, ratio=1
# step=1108,bili = 0.183444, ratio=1
# step=1109,bili = 0.183609, ratio=1
# step=1110,bili = 0.183775, ratio=1
# step=1111,bili = 0.183940, ratio=1
# step=1112,bili = 0.184106, ratio=1
# step=1113,bili = 0.184272, ratio=1
# step=1114,bili = 0.184437, ratio=1
# step=1115,bili = 0.184603, ratio=1
# step=1116,bili = 0.184768, ratio=1
# step=1117,bili = 0.184934, ratio=1
# step=1118,bili = 0.185099, ratio=1
# step=1119,bili = 0.185265, ratio=1
# step=1120,bili = 0.185430, ratio=1
# step=1121,bili = 0.185596, ratio=1
# step=1122,bili = 0.185762, ratio=1
# step=1123,bili = 0.185927, ratio=1
# step=1124,bili = 0.186093, ratio=1
# step=1125,bili = 0.186258, ratio=1
# step=1126,bili = 0.186424, ratio=1
# step=1127,bili = 0.186589, ratio=1
# step=1128,bili = 0.186755, ratio=1
# step=1129,bili = 0.186921, ratio=1
# step=1130,bili = 0.187086, ratio=1
# step=1131,bili = 0.187252, ratio=1
# step=1132,bili = 0.187417, ratio=1
# step=1133,bili = 0.187583, ratio=1
# step=1134,bili = 0.187748, ratio=1
# step=1135,bili = 0.187914, ratio=1
# step=1136,bili = 0.188079, ratio=1
# step=1137,bili = 0.188245, ratio=1
# step=1138,bili = 0.188411, ratio=1
# step=1139,bili = 0.188576, ratio=1
# step=1140,bili = 0.188742, ratio=1
# step=1141,bili = 0.188907, ratio=1
# step=1142,bili = 0.189073, ratio=1
# step=1143,bili = 0.189238, ratio=1
# step=1144,bili = 0.189404, ratio=1
# step=1145,bili = 0.189570, ratio=1
# step=1146,bili = 0.189735, ratio=1
# step=1147,bili = 0.189901, ratio=1
# step=1148,bili = 0.190066, ratio=1
# step=1149,bili = 0.190232, ratio=1
# step=1150,bili = 0.190397, ratio=1
# step=1151,bili = 0.190563, ratio=1
# step=1152,bili = 0.190728, ratio=1
# step=1153,bili = 0.190894, ratio=1
# step=1154,bili = 0.191060, ratio=1
# step=1155,bili = 0.191225, ratio=1
# step=1156,bili = 0.191391, ratio=1
# step=1157,bili = 0.191556, ratio=1
# step=1158,bili = 0.191722, ratio=1
# step=1159,bili = 0.191887, ratio=1
# step=1160,bili = 0.192053, ratio=1
# step=1161,bili = 0.192219, ratio=1
# step=1162,bili = 0.192384, ratio=1
# step=1163,bili = 0.192550, ratio=1
# step=1164,bili = 0.192715, ratio=1
# step=1165,bili = 0.192881, ratio=1
# step=1166,bili = 0.193046, ratio=1
# step=1167,bili = 0.193212, ratio=1
# step=1168,bili = 0.193377, ratio=1
# step=1169,bili = 0.193543, ratio=1
# step=1170,bili = 0.193709, ratio=1
# step=1171,bili = 0.193874, ratio=1
# step=1172,bili = 0.194040, ratio=1
# step=1173,bili = 0.194205, ratio=1
# step=1174,bili = 0.194371, ratio=1
# step=1175,bili = 0.194536, ratio=1
# step=1176,bili = 0.194702, ratio=1
# step=1177,bili = 0.194868, ratio=1
# step=1178,bili = 0.195033, ratio=1
# step=1179,bili = 0.195199, ratio=1
# step=1180,bili = 0.195364, ratio=1
# step=1181,bili = 0.195530, ratio=1
# step=1182,bili = 0.195695, ratio=1
# step=1183,bili = 0.195861, ratio=1
# step=1184,bili = 0.196026, ratio=1
# step=1185,bili = 0.196192, ratio=1
# step=1186,bili = 0.196358, ratio=1
# step=1187,bili = 0.196523, ratio=1
# step=1188,bili = 0.196689, ratio=1
# step=1189,bili = 0.196854, ratio=1
# step=1190,bili = 0.197020, ratio=1
# step=1191,bili = 0.197185, ratio=1
# step=1192,bili = 0.197351, ratio=1
# step=1193,bili = 0.197517, ratio=1
# step=1194,bili = 0.197682, ratio=1
# step=1195,bili = 0.197848, ratio=1
# step=1196,bili = 0.198013, ratio=1
# step=1197,bili = 0.198179, ratio=1
# step=1198,bili = 0.198344, ratio=1
# step=1199,bili = 0.198510, ratio=1
# step=1200,bili = 0.198675, ratio=1
# step=1201,bili = 0.198841, ratio=1
# step=1202,bili = 0.199007, ratio=1
# step=1203,bili = 0.199172, ratio=1
# step=1204,bili = 0.199338, ratio=1
# step=1205,bili = 0.199503, ratio=1
# step=1206,bili = 0.199669, ratio=1
# step=1207,bili = 0.199834, ratio=1
# step=1208,bili = 0.200000, ratio=1
# step=1209,bili = 0.200166, ratio=1
# step=1210,bili = 0.200331, ratio=1
# step=1211,bili = 0.200497, ratio=1
# step=1212,bili = 0.200662, ratio=1
# step=1213,bili = 0.200828, ratio=1
# step=1214,bili = 0.200993, ratio=1
# step=1215,bili = 0.201159, ratio=1
# step=1216,bili = 0.201325, ratio=1
# step=1217,bili = 0.201490, ratio=1
# step=1218,bili = 0.201656, ratio=1
# step=1219,bili = 0.201821, ratio=1
# step=1220,bili = 0.201987, ratio=1
# step=1221,bili = 0.202152, ratio=1
# step=1222,bili = 0.202318, ratio=1
# step=1223,bili = 0.202483, ratio=1
# step=1224,bili = 0.202649, ratio=1
# step=1225,bili = 0.202815, ratio=1
# step=1226,bili = 0.202980, ratio=1
# step=1227,bili = 0.203146, ratio=1
# step=1228,bili = 0.203311, ratio=1
# step=1229,bili = 0.203477, ratio=1
# step=1230,bili = 0.203642, ratio=1
# step=1231,bili = 0.203808, ratio=1
# step=1232,bili = 0.203974, ratio=1
# step=1233,bili = 0.204139, ratio=1
# step=1234,bili = 0.204305, ratio=1
# step=1235,bili = 0.204470, ratio=1
# step=1236,bili = 0.204636, ratio=1
# step=1237,bili = 0.204801, ratio=1
# step=1238,bili = 0.204967, ratio=1
# step=1239,bili = 0.205132, ratio=1
# step=1240,bili = 0.205298, ratio=1
# step=1241,bili = 0.205464, ratio=1
# step=1242,bili = 0.205629, ratio=1
# step=1243,bili = 0.205795, ratio=1
# step=1244,bili = 0.205960, ratio=1
# step=1245,bili = 0.206126, ratio=1
# step=1246,bili = 0.206291, ratio=1
# step=1247,bili = 0.206457, ratio=1
# step=1248,bili = 0.206623, ratio=1
# step=1249,bili = 0.206788, ratio=1
# step=1250,bili = 0.206954, ratio=1
# step=1251,bili = 0.207119, ratio=1
# step=1252,bili = 0.207285, ratio=1
# step=1253,bili = 0.207450, ratio=1
# step=1254,bili = 0.207616, ratio=1
# step=1255,bili = 0.207781, ratio=1
# step=1256,bili = 0.207947, ratio=1
# step=1257,bili = 0.208113, ratio=1
# step=1258,bili = 0.208278, ratio=1
# step=1259,bili = 0.208444, ratio=1
# step=1260,bili = 0.208609, ratio=1
# step=1261,bili = 0.208775, ratio=1
# step=1262,bili = 0.208940, ratio=1
# step=1263,bili = 0.209106, ratio=1
# step=1264,bili = 0.209272, ratio=1
# step=1265,bili = 0.209437, ratio=1
# step=1266,bili = 0.209603, ratio=1
# step=1267,bili = 0.209768, ratio=1
# step=1268,bili = 0.209934, ratio=1
# step=1269,bili = 0.210099, ratio=1
# step=1270,bili = 0.210265, ratio=1
# step=1271,bili = 0.210430, ratio=1
# step=1272,bili = 0.210596, ratio=1
# step=1273,bili = 0.210762, ratio=1
# step=1274,bili = 0.210927, ratio=1
# step=1275,bili = 0.211093, ratio=1
# step=1276,bili = 0.211258, ratio=1
# step=1277,bili = 0.211424, ratio=1
# step=1278,bili = 0.211589, ratio=1
# step=1279,bili = 0.211755, ratio=1
# step=1280,bili = 0.211921, ratio=1
# step=1281,bili = 0.212086, ratio=1
# step=1282,bili = 0.212252, ratio=1
# step=1283,bili = 0.212417, ratio=1
# step=1284,bili = 0.212583, ratio=1
# step=1285,bili = 0.212748, ratio=1
# step=1286,bili = 0.212914, ratio=1
# step=1287,bili = 0.213079, ratio=1
# step=1288,bili = 0.213245, ratio=1
# step=1289,bili = 0.213411, ratio=1
# step=1290,bili = 0.213576, ratio=1
# step=1291,bili = 0.213742, ratio=1
# step=1292,bili = 0.213907, ratio=1
# step=1293,bili = 0.214073, ratio=1
# step=1294,bili = 0.214238, ratio=1
# step=1295,bili = 0.214404, ratio=1
# step=1296,bili = 0.214570, ratio=1
# step=1297,bili = 0.214735, ratio=1
# step=1298,bili = 0.214901, ratio=1
# step=1299,bili = 0.215066, ratio=1
# step=1300,bili = 0.215232, ratio=1
# step=1301,bili = 0.215397, ratio=1
# step=1302,bili = 0.215563, ratio=1
# step=1303,bili = 0.215728, ratio=1
# step=1304,bili = 0.215894, ratio=1
# step=1305,bili = 0.216060, ratio=1
# step=1306,bili = 0.216225, ratio=1
# step=1307,bili = 0.216391, ratio=1
# step=1308,bili = 0.216556, ratio=1
# step=1309,bili = 0.216722, ratio=1
# step=1310,bili = 0.216887, ratio=1
# step=1311,bili = 0.217053, ratio=1
# step=1312,bili = 0.217219, ratio=1
# step=1313,bili = 0.217384, ratio=1
# step=1314,bili = 0.217550, ratio=1
# step=1315,bili = 0.217715, ratio=1
# step=1316,bili = 0.217881, ratio=1
# step=1317,bili = 0.218046, ratio=1
# step=1318,bili = 0.218212, ratio=1
# step=1319,bili = 0.218377, ratio=1
# step=1320,bili = 0.218543, ratio=1
# step=1321,bili = 0.218709, ratio=1
# step=1322,bili = 0.218874, ratio=1
# step=1323,bili = 0.219040, ratio=1
# step=1324,bili = 0.219205, ratio=1
# step=1325,bili = 0.219371, ratio=1
# step=1326,bili = 0.219536, ratio=1
# step=1327,bili = 0.219702, ratio=1
# step=1328,bili = 0.219868, ratio=1
# step=1329,bili = 0.220033, ratio=1
# step=1330,bili = 0.220199, ratio=1
# step=1331,bili = 0.220364, ratio=1
# step=1332,bili = 0.220530, ratio=1
# step=1333,bili = 0.220695, ratio=1
# step=1334,bili = 0.220861, ratio=1
# step=1335,bili = 0.221026, ratio=1
# step=1336,bili = 0.221192, ratio=1
# step=1337,bili = 0.221358, ratio=1
# step=1338,bili = 0.221523, ratio=1
# step=1339,bili = 0.221689, ratio=1
# step=1340,bili = 0.221854, ratio=1
# step=1341,bili = 0.222020, ratio=1
# step=1342,bili = 0.222185, ratio=1
# step=1343,bili = 0.222351, ratio=1
# step=1344,bili = 0.222517, ratio=1
# step=1345,bili = 0.222682, ratio=1
# step=1346,bili = 0.222848, ratio=1
# step=1347,bili = 0.223013, ratio=1
# step=1348,bili = 0.223179, ratio=1
# step=1349,bili = 0.223344, ratio=1
# step=1350,bili = 0.223510, ratio=1
# step=1351,bili = 0.223675, ratio=1
# step=1352,bili = 0.223841, ratio=1
# step=1353,bili = 0.224007, ratio=1
# step=1354,bili = 0.224172, ratio=1
# step=1355,bili = 0.224338, ratio=1
# step=1356,bili = 0.224503, ratio=1
# step=1357,bili = 0.224669, ratio=1
# step=1358,bili = 0.224834, ratio=1
# step=1359,bili = 0.225000, ratio=1
# step=1360,bili = 0.225166, ratio=1
# step=1361,bili = 0.225331, ratio=1
# step=1362,bili = 0.225497, ratio=1
# step=1363,bili = 0.225662, ratio=1
# step=1364,bili = 0.225828, ratio=1
# step=1365,bili = 0.225993, ratio=1
# step=1366,bili = 0.226159, ratio=1
# step=1367,bili = 0.226325, ratio=1
# step=1368,bili = 0.226490, ratio=1
# step=1369,bili = 0.226656, ratio=1
# step=1370,bili = 0.226821, ratio=1
# step=1371,bili = 0.226987, ratio=1
# step=1372,bili = 0.227152, ratio=1
# step=1373,bili = 0.227318, ratio=1
# step=1374,bili = 0.227483, ratio=1
# step=1375,bili = 0.227649, ratio=1
# step=1376,bili = 0.227815, ratio=1
# step=1377,bili = 0.227980, ratio=1
# step=1378,bili = 0.228146, ratio=1
# step=1379,bili = 0.228311, ratio=1
# step=1380,bili = 0.228477, ratio=1
# step=1381,bili = 0.228642, ratio=1
# step=1382,bili = 0.228808, ratio=1
# step=1383,bili = 0.228974, ratio=1
# step=1384,bili = 0.229139, ratio=1
# step=1385,bili = 0.229305, ratio=1
# step=1386,bili = 0.229470, ratio=1
# step=1387,bili = 0.229636, ratio=1
# step=1388,bili = 0.229801, ratio=1
# step=1389,bili = 0.229967, ratio=1
# step=1390,bili = 0.230132, ratio=1
# step=1391,bili = 0.230298, ratio=1
# step=1392,bili = 0.230464, ratio=1
# step=1393,bili = 0.230629, ratio=1
# step=1394,bili = 0.230795, ratio=1
# step=1395,bili = 0.230960, ratio=1
# step=1396,bili = 0.231126, ratio=1
# step=1397,bili = 0.231291, ratio=1
# step=1398,bili = 0.231457, ratio=1
# step=1399,bili = 0.231623, ratio=1
# step=1400,bili = 0.231788, ratio=1
# ...
# step=5670,bili = 0.938742, ratio=1
# step=5671,bili = 0.938907, ratio=1
# step=5672,bili = 0.939073, ratio=1
# step=5673,bili = 0.939238, ratio=1
# step=5674,bili = 0.939404, ratio=1
# step=5675,bili = 0.939570, ratio=1
# step=5676,bili = 0.939735, ratio=1
# step=5677,bili = 0.939901, ratio=1
# step=5678,bili = 0.940066, ratio=1
# step=5679,bili = 0.940232, ratio=1
# step=5680,bili = 0.940397, ratio=1
# step=5681,bili = 0.940563, ratio=1
# step=5682,bili = 0.940728, ratio=1
# step=5683,bili = 0.940894, ratio=1
# step=5684,bili = 0.941060, ratio=1
# step=5685,bili = 0.941225, ratio=1
# step=5686,bili = 0.941391, ratio=1
# step=5687,bili = 0.941556, ratio=1
# step=5688,bili = 0.941722, ratio=1
# step=5689,bili = 0.941887, ratio=1
# step=5690,bili = 0.942053, ratio=1
# step=5691,bili = 0.942219, ratio=1
# step=5692,bili = 0.942384, ratio=1
# step=5693,bili = 0.942550, ratio=1
# step=5694,bili = 0.942715, ratio=1
# step=5695,bili = 0.942881, ratio=1
# step=5696,bili = 0.943046, ratio=1
# step=5697,bili = 0.943212, ratio=1
# step=5698,bili = 0.943377, ratio=1
# step=5699,bili = 0.943543, ratio=1
# step=5700,bili = 0.943709, ratio=1
# step=5701,bili = 0.943874, ratio=1
# step=5702,bili = 0.944040, ratio=1
# step=5703,bili = 0.944205, ratio=1
# step=5704,bili = 0.944371, ratio=1
# step=5705,bili = 0.944536, ratio=1
# step=5706,bili = 0.944702, ratio=1
# step=5707,bili = 0.944868, ratio=1
# step=5708,bili = 0.945033, ratio=1
# step=5709,bili = 0.945199, ratio=1
# step=5710,bili = 0.945364, ratio=1
# step=5711,bili = 0.945530, ratio=1
# step=5712,bili = 0.945695, ratio=1
# step=5713,bili = 0.945861, ratio=1
# step=5714,bili = 0.946026, ratio=1
# step=5715,bili = 0.946192, ratio=1
# step=5716,bili = 0.946358, ratio=1
# step=5717,bili = 0.946523, ratio=1
# step=5718,bili = 0.946689, ratio=1
# step=5719,bili = 0.946854, ratio=1
# step=5720,bili = 0.947020, ratio=1
# step=5721,bili = 0.947185, ratio=1
# step=5722,bili = 0.947351, ratio=1
# step=5723,bili = 0.947517, ratio=1
# step=5724,bili = 0.947682, ratio=1
# step=5725,bili = 0.947848, ratio=1
# step=5726,bili = 0.948013, ratio=1
# step=5727,bili = 0.948179, ratio=1
# step=5728,bili = 0.948344, ratio=1
# step=5729,bili = 0.948510, ratio=1
# step=5730,bili = 0.948675, ratio=1
# step=5731,bili = 0.948841, ratio=1
# step=5732,bili = 0.949007, ratio=1
# step=5733,bili = 0.949172, ratio=1
# step=5734,bili = 0.949338, ratio=1
# step=5735,bili = 0.949503, ratio=1
# step=5736,bili = 0.949669, ratio=1
# step=5737,bili = 0.949834, ratio=1
# step=5738,bili = 0.950000, ratio=1
# step=5739,bili = 0.950166, ratio=1
# step=5740,bili = 0.950331, ratio=1
# step=5741,bili = 0.950497, ratio=1
# step=5742,bili = 0.950662, ratio=1
# step=5743,bili = 0.950828, ratio=1
# step=5744,bili = 0.950993, ratio=1
# step=5745,bili = 0.951159, ratio=1
# step=5746,bili = 0.951325, ratio=1
# step=5747,bili = 0.951490, ratio=1
# step=5748,bili = 0.951656, ratio=1
# step=5749,bili = 0.951821, ratio=1
# step=5750,bili = 0.951987, ratio=1
# step=5751,bili = 0.952152, ratio=1
# step=5752,bili = 0.952318, ratio=1
# step=5753,bili = 0.952483, ratio=1
# step=5754,bili = 0.952649, ratio=1
# step=5755,bili = 0.952815, ratio=1
# step=5756,bili = 0.952980, ratio=1
# step=5757,bili = 0.953146, ratio=1
# step=5758,bili = 0.953311, ratio=1
# step=5759,bili = 0.953477, ratio=1
# step=5760,bili = 0.953642, ratio=1
# step=5761,bili = 0.953808, ratio=1
# step=5762,bili = 0.953974, ratio=1
# step=5763,bili = 0.954139, ratio=1
# step=5764,bili = 0.954305, ratio=1
# step=5765,bili = 0.954470, ratio=1
# step=5766,bili = 0.954636, ratio=1
# step=5767,bili = 0.954801, ratio=1
# step=5768,bili = 0.954967, ratio=1
# step=5769,bili = 0.955132, ratio=1
# step=5770,bili = 0.955298, ratio=1
# step=5771,bili = 0.955464, ratio=1
# step=5772,bili = 0.955629, ratio=1
# step=5773,bili = 0.955795, ratio=1
# step=5774,bili = 0.955960, ratio=1
# step=5775,bili = 0.956126, ratio=1
# step=5776,bili = 0.956291, ratio=1
# step=5777,bili = 0.956457, ratio=1
# step=5778,bili = 0.956623, ratio=1
# step=5779,bili = 0.956788, ratio=1
# step=5780,bili = 0.956954, ratio=1
# step=5781,bili = 0.957119, ratio=1
# step=5782,bili = 0.957285, ratio=1
# step=5783,bili = 0.957450, ratio=1
# step=5784,bili = 0.957616, ratio=1
# step=5785,bili = 0.957781, ratio=1
# step=5786,bili = 0.957947, ratio=1
# step=5787,bili = 0.958113, ratio=1
# step=5788,bili = 0.958278, ratio=1
# step=5789,bili = 0.958444, ratio=1
# step=5790,bili = 0.958609, ratio=1
# step=5791,bili = 0.958775, ratio=1
# step=5792,bili = 0.958940, ratio=1
# step=5793,bili = 0.959106, ratio=1
# step=5794,bili = 0.959272, ratio=1
# step=5795,bili = 0.959437, ratio=1
# step=5796,bili = 0.959603, ratio=1
# step=5797,bili = 0.959768, ratio=1
# step=5798,bili = 0.959934, ratio=1
# step=5799,bili = 0.960099, ratio=1
# step=5800,bili = 0.960265, ratio=1
# step=5801,bili = 0.960430, ratio=1
# step=5802,bili = 0.960596, ratio=1
# step=5803,bili = 0.960762, ratio=1
# step=5804,bili = 0.960927, ratio=1
# step=5805,bili = 0.961093, ratio=1
# step=5806,bili = 0.961258, ratio=1
# step=5807,bili = 0.961424, ratio=1
# step=5808,bili = 0.961589, ratio=1
# step=5809,bili = 0.961755, ratio=1
# step=5810,bili = 0.961921, ratio=1
# step=5811,bili = 0.962086, ratio=1
# step=5812,bili = 0.962252, ratio=1
# step=5813,bili = 0.962417, ratio=1
# step=5814,bili = 0.962583, ratio=1
# step=5815,bili = 0.962748, ratio=1
# step=5816,bili = 0.962914, ratio=1
# step=5817,bili = 0.963079, ratio=1
# step=5818,bili = 0.963245, ratio=1
# step=5819,bili = 0.963411, ratio=1
# step=5820,bili = 0.963576, ratio=1
# step=5821,bili = 0.963742, ratio=1
# step=5822,bili = 0.963907, ratio=1
# step=5823,bili = 0.964073, ratio=1
# step=5824,bili = 0.964238, ratio=1
# step=5825,bili = 0.964404, ratio=1
# step=5826,bili = 0.964570, ratio=1
# step=5827,bili = 0.964735, ratio=1
# step=5828,bili = 0.964901, ratio=1
# step=5829,bili = 0.965066, ratio=1
# step=5830,bili = 0.965232, ratio=1
# step=5831,bili = 0.965397, ratio=1
# step=5832,bili = 0.965563, ratio=1
# step=5833,bili = 0.965728, ratio=1
# step=5834,bili = 0.965894, ratio=1
# step=5835,bili = 0.966060, ratio=1
# step=5836,bili = 0.966225, ratio=1
# step=5837,bili = 0.966391, ratio=1
# step=5838,bili = 0.966556, ratio=1
# step=5839,bili = 0.966722, ratio=1
# step=5840,bili = 0.966887, ratio=1
# step=5841,bili = 0.967053, ratio=1
# step=5842,bili = 0.967219, ratio=1
# step=5843,bili = 0.967384, ratio=1
# step=5844,bili = 0.967550, ratio=1
# step=5845,bili = 0.967715, ratio=1
# step=5846,bili = 0.967881, ratio=1
# step=5847,bili = 0.968046, ratio=1
# step=5848,bili = 0.968212, ratio=1
# step=5849,bili = 0.968377, ratio=1
# step=5850,bili = 0.968543, ratio=1
# step=5851,bili = 0.968709, ratio=1
# step=5852,bili = 0.968874, ratio=1
# step=5853,bili = 0.969040, ratio=1
# step=5854,bili = 0.969205, ratio=1
# step=5855,bili = 0.969371, ratio=1
# step=5856,bili = 0.969536, ratio=1
# step=5857,bili = 0.969702, ratio=1
# step=5858,bili = 0.969868, ratio=1
# step=5859,bili = 0.970033, ratio=1
# step=5860,bili = 0.970199, ratio=1
# step=5861,bili = 0.970364, ratio=1
# step=5862,bili = 0.970530, ratio=1
# step=5863,bili = 0.970695, ratio=1
# step=5864,bili = 0.970861, ratio=1
# step=5865,bili = 0.971026, ratio=1
# step=5866,bili = 0.971192, ratio=1
# step=5867,bili = 0.971358, ratio=1
# step=5868,bili = 0.971523, ratio=1
# step=5869,bili = 0.971689, ratio=1
# step=5870,bili = 0.971854, ratio=1
# step=5871,bili = 0.972020, ratio=1
# step=5872,bili = 0.972185, ratio=1
# step=5873,bili = 0.972351, ratio=1
# step=5874,bili = 0.972517, ratio=1
# step=5875,bili = 0.972682, ratio=1
# step=5876,bili = 0.972848, ratio=1
# step=5877,bili = 0.973013, ratio=1
# step=5878,bili = 0.973179, ratio=1
# step=5879,bili = 0.973344, ratio=1
# step=5880,bili = 0.973510, ratio=1
# step=5881,bili = 0.973675, ratio=1
# step=5882,bili = 0.973841, ratio=1
# step=5883,bili = 0.974007, ratio=1
# step=5884,bili = 0.974172, ratio=1
# step=5885,bili = 0.974338, ratio=1
# step=5886,bili = 0.974503, ratio=1
# step=5887,bili = 0.974669, ratio=1
# step=5888,bili = 0.974834, ratio=1
# step=5889,bili = 0.975000, ratio=1
# step=5890,bili = 0.975166, ratio=1
# step=5891,bili = 0.975331, ratio=1
# step=5892,bili = 0.975497, ratio=1
# step=5893,bili = 0.975662, ratio=1
# step=5894,bili = 0.975828, ratio=1
# step=5895,bili = 0.975993, ratio=1
# step=5896,bili = 0.976159, ratio=1
# step=5897,bili = 0.976325, ratio=1
# step=5898,bili = 0.976490, ratio=1
# step=5899,bili = 0.976656, ratio=1
# step=5900,bili = 0.976821, ratio=1
# step=5901,bili = 0.976987, ratio=1
# step=5902,bili = 0.977152, ratio=1
# step=5903,bili = 0.977318, ratio=1
# step=5904,bili = 0.977483, ratio=1
# step=5905,bili = 0.977649, ratio=1
# step=5906,bili = 0.977815, ratio=1
# step=5907,bili = 0.977980, ratio=1
# step=5908,bili = 0.978146, ratio=1
# step=5909,bili = 0.978311, ratio=1
# step=5910,bili = 0.978477, ratio=1
# step=5911,bili = 0.978642, ratio=1
# step=5912,bili = 0.978808, ratio=1
# step=5913,bili = 0.978974, ratio=1
# step=5914,bili = 0.979139, ratio=1
# step=5915,bili = 0.979305, ratio=1
# step=5916,bili = 0.979470, ratio=1
# step=5917,bili = 0.979636, ratio=1
# step=5918,bili = 0.979801, ratio=1
# step=5919,bili = 0.979967, ratio=1
# step=5920,bili = 0.980132, ratio=1
# step=5921,bili = 0.980298, ratio=1
# step=5922,bili = 0.980464, ratio=1
# step=5923,bili = 0.980629, ratio=1
# step=5924,bili = 0.980795, ratio=1
# step=5925,bili = 0.980960, ratio=1
# step=5926,bili = 0.981126, ratio=1
# step=5927,bili = 0.981291, ratio=1
# step=5928,bili = 0.981457, ratio=1
# step=5929,bili = 0.981623, ratio=1
# step=5930,bili = 0.981788, ratio=1
# step=5931,bili = 0.981954, ratio=1
# step=5932,bili = 0.982119, ratio=1
# step=5933,bili = 0.982285, ratio=1
# step=5934,bili = 0.982450, ratio=1
# step=5935,bili = 0.982616, ratio=1
# step=5936,bili = 0.982781, ratio=1
# step=5937,bili = 0.982947, ratio=1
# step=5938,bili = 0.983113, ratio=1
# step=5939,bili = 0.983278, ratio=1
# step=5940,bili = 0.983444, ratio=1
# step=5941,bili = 0.983609, ratio=1
# step=5942,bili = 0.983775, ratio=1
# step=5943,bili = 0.983940, ratio=1
# step=5944,bili = 0.984106, ratio=1
# step=5945,bili = 0.984272, ratio=1
# step=5946,bili = 0.984437, ratio=1
# step=5947,bili = 0.984603, ratio=1
# step=5948,bili = 0.984768, ratio=1
# step=5949,bili = 0.984934, ratio=1
# step=5950,bili = 0.985099, ratio=1
# step=5951,bili = 0.985265, ratio=1
# step=5952,bili = 0.985430, ratio=1
# step=5953,bili = 0.985596, ratio=1
# step=5954,bili = 0.985762, ratio=1
# step=5955,bili = 0.985927, ratio=1
# step=5956,bili = 0.986093, ratio=1
# step=5957,bili = 0.986258, ratio=1
# step=5958,bili = 0.986424, ratio=1
# step=5959,bili = 0.986589, ratio=1
# step=5960,bili = 0.986755, ratio=1
# step=5961,bili = 0.986921, ratio=1
# step=5962,bili = 0.987086, ratio=1
# step=5963,bili = 0.987252, ratio=1
# step=5964,bili = 0.987417, ratio=1
# step=5965,bili = 0.987583, ratio=1
# step=5966,bili = 0.987748, ratio=1
# step=5967,bili = 0.987914, ratio=1
# step=5968,bili = 0.988079, ratio=1
# step=5969,bili = 0.988245, ratio=1
# step=5970,bili = 0.988411, ratio=1
# step=5971,bili = 0.988576, ratio=1
# step=5972,bili = 0.988742, ratio=1
# step=5973,bili = 0.988907, ratio=1
# step=5974,bili = 0.989073, ratio=1
# step=5975,bili = 0.989238, ratio=1
# step=5976,bili = 0.989404, ratio=1
# step=5977,bili = 0.989570, ratio=1
# step=5978,bili = 0.989735, ratio=1
# step=5979,bili = 0.989901, ratio=1
# step=5980,bili = 0.990066, ratio=1
# step=5981,bili = 0.990232, ratio=1
# step=5982,bili = 0.990397, ratio=1
# step=5983,bili = 0.990563, ratio=1
# step=5984,bili = 0.990728, ratio=1
# step=5985,bili = 0.990894, ratio=1
# step=5986,bili = 0.991060, ratio=1
# step=5987,bili = 0.991225, ratio=1
# step=5988,bili = 0.991391, ratio=1
# step=5989,bili = 0.991556, ratio=1
# step=5990,bili = 0.991722, ratio=1
# step=5991,bili = 0.991887, ratio=1
# step=5992,bili = 0.992053, ratio=1
# step=5993,bili = 0.992219, ratio=1
# step=5994,bili = 0.992384, ratio=1
# step=5995,bili = 0.992550, ratio=1
# step=5996,bili = 0.992715, ratio=1
# step=5997,bili = 0.992881, ratio=1
# step=5998,bili = 0.993046, ratio=1
# step=5999,bili = 0.993212, ratio=1
# step=6000,bili = 0.993377, ratio=1
# step=6001,bili = 0.993543, ratio=1
# step=6002,bili = 0.993709, ratio=1
# step=6003,bili = 0.993874, ratio=1
# step=6004,bili = 0.994040, ratio=1
# step=6005,bili = 0.994205, ratio=1
# step=6006,bili = 0.994371, ratio=1
# step=6007,bili = 0.994536, ratio=1
# step=6008,bili = 0.994702, ratio=1
# step=6009,bili = 0.994868, ratio=1
# step=6010,bili = 0.995033, ratio=1
# step=6011,bili = 0.995199, ratio=1
# step=6012,bili = 0.995364, ratio=1
# step=6013,bili = 0.995530, ratio=1
# step=6014,bili = 0.995695, ratio=1
# step=6015,bili = 0.995861, ratio=1
# step=6016,bili = 0.996026, ratio=1
# step=6017,bili = 0.996192, ratio=1
# step=6018,bili = 0.996358, ratio=1
# step=6019,bili = 0.996523, ratio=1
# step=6020,bili = 0.996689, ratio=1
# step=6021,bili = 0.996854, ratio=1
# step=6022,bili = 0.997020, ratio=1
# step=6023,bili = 0.997185, ratio=1
# step=6024,bili = 0.997351, ratio=1
# step=6025,bili = 0.997517, ratio=1
# step=6026,bili = 0.997682, ratio=1
# step=6027,bili = 0.997848, ratio=1
# step=6028,bili = 0.998013, ratio=1
# step=6029,bili = 0.998179, ratio=1
# step=6030,bili = 0.998344, ratio=1
# step=6031,bili = 0.998510, ratio=1
# step=6032,bili = 0.998675, ratio=1
# step=6033,bili = 0.998841, ratio=1
# step=6034,bili = 0.999007, ratio=1
# step=6035,bili = 0.999172, ratio=1
# step=6036,bili = 0.999338, ratio=1
# step=6037,bili = 0.999503, ratio=1
# step=6038,bili = 0.999669, ratio=1
# step=6039,bili = 0.999834, ratio=1
# randomSelect: 7.004407644271851
# init: 0.6444175243377686
# step = 0
# 1.7881393432617188e-05
# step = 1
# 138.86939191818237
# step = 2
# 277.1002688407898
# step = 3
# 415.8398013114929
# step = 4
# 554.2151198387146
# step = 5
# 693.1711919307709
# /home/tensor/.local/lib/python3.6/site-packages/ipykernel_launcher.py:77: RuntimeWarning: invalid value encountered in true_divide
# step = 6
# 831.7275912761688
# step = 7
# 969.9684729576111
# step = 8
# 1108.9943044185638
# step = 9
# 1247.1849224567413
# step = 10
# 1385.3097624778748
# step = 11
# 1523.6553888320923
# step = 12
# 1662.5330357551575
# step = 13
# 1800.7839167118073
# step = 14
# 1939.0890069007874
# step = 15
# 2078.279142141342
# step = 16
# 2216.7130074501038
# step = 17
# 2355.7788214683533
# step = 18
# 2494.114716053009
# step = 19
# 2633.2042899131775
# step = 20
# 2771.5641589164734
# step = 21
# 2910.9221420288086
# step = 22
# 3049.745434522629
# step = 23
# 3188.971097946167
# step = 24
# 3327.538229227066
# step = 25
# 3468.348032951355
# step = 26
# 3607.384178161621
# step = 27
# 3747.7595512866974
# step = 28
# 3886.9192323684692
# step = 29
# 4026.647155046463
# step = 30
# 4165.521398305893
# step = 31
# 4305.159564256668
# step = 32
# 4444.124756813049
# step = 33
# 4584.545855760574
# step = 34
# 4723.420079469681
# step = 35
# 4866.144344091415
# step = 36
# 5006.011565208435
# step = 37
# 5144.8225293159485
# step = 38
# 5286.3613131046295
# step = 39
# 5425.334845542908
# step = 40
# 5564.2938985824585
# step = 41
# 5702.522829055786
# step = 42
# 5840.837290763855
# step = 43
# 5979.923408508301
# step = 44
# 6118.671661376953
# step = 45
# 6258.191370487213
# step = 46
# 6396.833395242691
# step = 47
# 6536.117683887482
# step = 48
# 6674.856325387955
# step = 49
# 6813.612760305405
# step = 50
# 6952.61242556572
# step = 51
# 7091.6958174705505
# step = 52
# 7230.531221866608
# step = 53
# 7369.105750083923
# step = 54
# 7508.785931110382
# step = 55
# 7647.662792682648
# step = 56
# 7786.910873889923
# step = 57
# 7925.380534172058
# step = 58
# 8064.987138271332
# step = 59
# 8203.85615491867
# step = 60
# 8343.17699098587
# step = 61
# 8481.626347064972
# step = 62
# 8620.773485660553
# step = 63
# 8759.289301395416
# step = 64
# 8897.732113838196
# step = 65
# 9036.237030267715
# step = 66
# 9175.474903345108
# step = 67
# 9314.198299646378
# step = 68
# 9452.827322006226
# step = 69
# 9592.367840051651
# step = 70
# 9730.947338581085
# step = 71
# 9870.262105941772
# step = 72
# 10009.08113360405
# step = 73
# 10148.731106996536
# step = 74
# 10287.76613855362
# step = 75
# 10426.912078619003
# step = 76
# 10566.378424882889
# step = 77
# 10704.820157766342
# step = 78
# 10844.318541526794
# step = 79
# 10982.845256567001
# step = 80
# 11121.527182340622
# step = 81
# 11261.014415740967
# step = 82
# 11400.364549398422
# step = 83
# 11540.083468437195
# step = 84
# 11678.926746845245
# step = 85
# 11817.78054857254
# step = 86
# 11957.488908052444
# step = 87
# 12096.344835996628
# step = 88
# 12235.227794885635
# step = 89
# 12374.535119533539
# step = 90
# 12512.829989433289
# step = 91
# 12651.20152759552
# step = 92
# 12790.70838522911
# step = 93
# 12929.34276342392
# step = 94
# 13068.562824487686
# step = 95
# 13207.006142377853
# step = 96
# 13346.337684631348
# step = 97
# 13485.078300952911
# step = 98
# 13624.300835132599
# step = 99
# 13763.357437849045

# %%
prediction = lfm.call()
# Out:
# recommend: 19.807056188583374
# precision: 0.01774624373956594
# recall: 0.008502231535840545
# coverage: 0.0027107617240444567
# popularity: 6.464530507787041
